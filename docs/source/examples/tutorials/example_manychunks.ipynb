# %% [markdown]
# # MuonDataLib Example: Slicing data
#
# In this example we have a simple code for creating a series of

# %%
from MuonDataLib.data.loader.load_events import load_events
import os

file_name = 'HIFI00193325.nxs'
input_file = os.path.join('..', 'Data_files', file_name)

data = load_events(input_file, 64)
frame_start_times = data.get_frame_start_times()

# approx length of 1 frame
dt = frame_start_times[1] - frame_start_times[0] - 0.1

total_time = frame_start_times[-1] + dt

print(total_time)
N_chunks = 100
for chunk in range(N_chunks):
    data.clear_time_filters()
    slice_width = chunk * total_time / (2.*N_chunks)
    if chunk > 0:
        data.add_time_filter(f"filter 1", frame_start_times[0], slice_width) #, start_slice + chunk_size*total_time)
        data.add_time_filter(f"filter 2", total_time - slice_width, total_time)
    data._dict['detector_1']._dict['time_zero'] = 40
    data._dict['detector_1']._dict['first_good'] = 43*.016
    output_name = f'HIFI00193325_chunk{chunk+1}.nxs'
    output_file = os.path.join('..', 'Output_files', output_name)
    print(chunk, data.report_filters())
    data.save_histograms(output_file)
